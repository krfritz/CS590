# %%
OL_Ratio <- c(76.2, 82.1, 78.9, 74.3, 77.7)
Leaf_Spot <- c(5.5, 7.2, 6.5, 4.2, 3.1)
Drought <- c(TRUE, FALSE, TRUE, FALSE, FALSE)
df <- data.frame(OL_Ratio, Leaf_Spot, Drought)
rownames(df) <- c('N12006', 'N13003', 'N13042', 'N14002', 'N16021')
df
# Out:
#        OL_Ratio Leaf_Spot Drought
# N12006 76.2     5.5        TRUE
# N13003 82.1     7.2       FALSE
# N13042 78.9     6.5        TRUE
# N14002 74.3     4.2       FALSE
# N16021 77.7     3.1       FALSE

# %%
subset(df, Drought == FALSE)
# Out:
#        OL_Ratio Leaf_Spot Drought
# N13003 82.1     7.2       FALSE
# N14002 74.3     4.2       FALSE
# N16021 77.7     3.1       FALSE

# %%
setwd('C:\\Users\\krfritz\\NC State PB&G Dropbox\\Katelyn Fritz\\R & Python class\\Course Data')
getwd()
peanut_lines <- read.csv ('peanut_lines.csv')
peanut_lines
# Out:
# [1] "C:/Users/krfritz/NC State PB&G Dropbox/Katelyn Fritz/R & Python class/Course Data"
#     NC_Accession
# 1   ACI WT09-0761
# 2   ACI WT11-0351
# 3   ACI WT12-0226
# 4   ACI WT12-0419
# 5   ACI WT12-0420
# 6   ACI WT12-0433
# 7   Bailey
# 8   Bailey II
# 9   Brantley
# 10  CHAMPS
# 11  Emery
# 12  Florida Fancy
# 13  Florida-07
# 14  FloriGiant
# 15  FloRun 107
# 16  FloRun 157
# 17  FloRun 331
# 18  Georgia Green
# 19  Georgia-06G
# 20  Georgia-07W
# 21  Georgia-09B
# 22  Georgia-11J
# 23  Georgia-12Y
# 24  Gregory
# 25  Harris 1
# 26  HTS 02-06
# 27  HTS 15-04ol
# 28  N03088
# 29  N04067
# 30  N04072
# ... ...
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 851
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 859
#     Identity.or.Parentage
# 1   ACI WT09-0761
# 2   ACI WT11-0351
# 3   ACI WT12-0226
# 4   ACI WT12-0419
# 5   ACI WT12-0420
# 6   ACI WT12-0433
# 7   NC 12C*2 / N96076L
# ...

# %%
peanut_disease <- read.table('peanut_disease.txt', sep='\t', header=TRUE)
peanut_disease
# Out:
#      Year Location Name  Label                                  NC_Accession
# 1    2010 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 2    2010 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 3    2011 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 4    2011 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 5    2012 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 6    2012 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 7    2013 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 8    2013 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 9    2014 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 10   2014 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 11   2015 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# 12   2015 LEW      ATP-L Advanced Testing Program - Leafspot    Bailey
# ...

# %%
colnames(peanut_lines)
colnames(peanut_disease)
# Out:
# [1] "NC_Accession"          "Identity.or.Parentage" "Pedigree"
# [4] "FAG"
# [1] "Year"         "Location"     "Name"         "Label"        "NC_Accession"
# [6] "Rating"       "Disease"

# %%
disease_data <- merge(peanut_lines, peanut_disease, by.x = 'NC_Accession', by.y= 'NC_Accession', all)
disease_data
# Out:
#      NC_Accession Identity.or.Parentage Pedigree                   FAG   Year
# 1    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2010
# 2    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2016
# 3    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2010
# 4    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2016
# 5    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2015
# 6    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2014
# 7    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2010
# 8    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2017
# 9    Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2013
# 10   Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2010
# 11   Bailey       NC 12C*2 / N96076L    BC1F1-06-01-S-03-S-05: F09 + +   2016
# ...

# %%
leaf.spot<- subset(disease_data, Rating== 'LS')
leaf.spot
# Out:
#      NC_Accession
# 10   Bailey
# 14   Bailey
# 20   Bailey
# 30   Bailey
# 33   Bailey
# 34   Bailey
# 38   Bailey
# 39   Bailey
# 42   Bailey
# 45   Bailey
# 48   Bailey
# 53   Bailey
# 54   Bailey
# 59   Bailey
# 61   Bailey
# 63   Bailey II
# 65   Bailey II
# 68   Bailey II
# 69   Bailey II
# 70   Bailey II
# 71   Bailey II
# 73   Bailey II
# 79   Bailey II
# 100  Brantley
# 104  Brantley
# 105  Brantley
# 108  CHAMPS
# 109  CHAMPS
# 115  CHAMPS
# 118  CHAMPS
# ...  ...
# 2597 Sullivan
# 2598 Sullivan
# 2599 Sullivan
# 2600 Sullivan
# 2601 Sullivan
# 2602 Sullivan
# 2603 Sullivan
# 2604 Sullivan
# 2605 Sullivan
# 2606 Sullivan
# 2616 Sullivan
# 2649 TUFRunner 511
# 2652 VA 98R
# 2653 VA 98R
# 2660 Wynne
# 2661 Wynne
# 2662 Wynne
# 2663 Wynne
# 2664 Wynne
# 2665 Wynne
# 2666 Wynne
# 2667 Wynne
# 2668 Wynne
# 2669 Wynne
# 2670 Wynne
# 2671 Wynne
# 2672 Wynne
# 2673 Wynne
# 2674 Wynne
# 2675 Wynne
#      Identity.or.Parentage
# 10   NC 12C*2 / N96076L
# 14   NC 12C*2 / N96076L
# ...

# %%
leaf.spot <- leaf.spot[!is.na(leaf.spot$Disease),]

# %%
mean(leaf.spot$Disease[leaf.spot$Year == 2017])
# Out:
# [1] 7.514687

# %%
line_names <- c('Bailey', 'Bailey II', 'Wynne', 'Sullivan', 'Emery', 'N96076')
leaf.spot <- leaf.spot[leaf.spot$NC_Accession %in% line_names,]
leaf.spot
# Out:
#      NC_Accession
# 10   Bailey
# 14   Bailey
# 20   Bailey
# 30   Bailey
# 33   Bailey
# 34   Bailey
# 38   Bailey
# 39   Bailey
# 42   Bailey
# 45   Bailey
# 48   Bailey
# 53   Bailey
# 54   Bailey
# 59   Bailey
# 61   Bailey
# 63   Bailey II
# 65   Bailey II
# 68   Bailey II
# 69   Bailey II
# 70   Bailey II
# 71   Bailey II
# 73   Bailey II
# 79   Bailey II
# 126  Emery
# 128  Emery
# 147  Emery
# 150  Emery
# 151  Emery
# 156  Emery
# 157  Emery
# ...  ...
# 2594 Sullivan
# 2595 Sullivan
# 2596 Sullivan
# 2597 Sullivan
# 2598 Sullivan
# 2599 Sullivan
# 2600 Sullivan
# 2601 Sullivan
# 2602 Sullivan
# 2603 Sullivan
# 2604 Sullivan
# 2605 Sullivan
# 2606 Sullivan
# 2616 Sullivan
# 2660 Wynne
# 2661 Wynne
# 2662 Wynne
# 2663 Wynne
# 2664 Wynne
# 2665 Wynne
# 2666 Wynne
# 2667 Wynne
# 2668 Wynne
# 2669 Wynne
# 2670 Wynne
# 2671 Wynne
# 2672 Wynne
# 2673 Wynne
# 2674 Wynne
# 2675 Wynne
#      Identity.or.Parentage
# 10   NC 12C*2 / N96076L
# 14   NC 12C*2 / N96076L
# ...

# %%
help(aggregate)

# %%
leaf.spot <- aggregate(list(Disease = leaf.spot$Disease), list(NC_Accession = leaf.spot$NC_Accession), mean)

# %%
leaf.spot
# Out:
#   NC_Accession Disease
# 1 Bailey       4.828000
# 2 Bailey II    4.981250
# 3 Emery        6.089167
# 4 Sullivan     5.048667
# 5 Wynne        5.545625

# %%
library(xlsx)
write.xlsx(leaf.spot, "Leaf Spot.xlsx")
